# %% [markdown]
# #### Importing Libraries

# %%
#import the libraries
import pandas as pd
import numpy as np
#import the plotting libraries
import warnings
warnings.filterwarnings("ignore")
#import the plotting libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #### Read CSV file

# %%
pd.options.display.float_format = '{:.0f}'.format
df=pd.read_csv("C:\\Users\\karth\\Python\\Course2\\loan_details\\loan.csv")
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000             4975   36 months
# 1  1077430    1314167       2500         2500             2500   60 months
# 2  1077175    1313524       2400         2400             2400   36 months
# 3  1076863    1277178      10000        10000            10000   36 months
# 4  1075358    1311748       3000         3000             3000   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%          163     B        B2  ...                NaN
# 1   15.27%           60     C        C4  ...                NaN
# 2   15.96%           84     C        C5  ...                NaN
# 3   13.49%          339     C        C1  ...                NaN
# 4   12.69%           68     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                    0
# 1                NaN            NaN               NaN                    0
# 2                NaN            NaN               NaN                    0
# 3                NaN            NaN               NaN                    0
# 4                NaN            NaN               NaN                    0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0         0             NaN               NaN            NaN
# 1         0             NaN               NaN            NaN
# 2         0             NaN               NaN            NaN
# 3         0             NaN               NaN            NaN
# 4         0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %%
df.shape
# Out:
# (39717, 111)

# %% [markdown]
# # Data Handling and Cleaning

# %% [markdown]
# #### Identifying and dropping null values

# %%
df.isnull().sum(axis=0)
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        40
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
# drop columns with all NaN's
df = df.dropna(axis=1, how='all')
df.shape
# Out:
# (39717, 61)

# %%
df.isnull().sum()
# Out:
# id                              0
# member_id                       0
# loan_amnt                       0
# funded_amnt                     0
# funded_amnt_inv                 0
#                             ...
# chargeoff_within_12_mths       56
# delinq_amnt                     1
# percent_bc_gt_75            39716
# pub_rec_bankruptcies          697
# tax_liens                      40
# Length: 61, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 61 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           39717 non-null  int64
#  1   member_id                    39717 non-null  int64
#  2   loan_amnt                    39717 non-null  int64
#  3   funded_amnt                  39717 non-null  int64
#  4   funded_amnt_inv              39717 non-null  float64
#  5   term                         39717 non-null  object
#  6   int_rate                     39717 non-null  object
#  7   installment                  39717 non-null  float64
#  8   grade                        39717 non-null  object
#  9   sub_grade                    39717 non-null  object
#  10  emp_title                    37258 non-null  object
#  11  emp_length                   38642 non-null  object
#  12  home_ownership               39717 non-null  object
#  13  annual_inc                   39717 non-null  float64
#  14  verification_status          39717 non-null  object
#  15  issue_d                      39717 non-null  object
#  16  loan_status                  39717 non-null  object
#  17  pymnt_plan                   39717 non-null  object
#  18  url                          39717 non-null  object
#  19  desc                         26775 non-null  object
#  20  purpose                      39717 non-null  object
#  21  title                        39706 non-null  object
#  22  zip_code                     39717 non-null  object
#  23  addr_state                   39717 non-null  object
#  24  dti                          39717 non-null  float64
#  25  delinq_2yrs                  39717 non-null  object
#  26  earliest_cr_line             39717 non-null  object
#  27  inq_last_6mths               39717 non-null  int64
#  28  mths_since_last_delinq       14034 non-null  float64
#  29  mths_since_last_record       2787 non-null   float64
#  30  open_acc                     39717 non-null  int64
#  31  pub_rec                      39717 non-null  int64
#  32  revol_bal                    39717 non-null  object
#  33  revol_util                   39667 non-null  object
#  34  total_acc                    39717 non-null  object
#  35  initial_list_status          39717 non-null  object
#  36  out_prncp                    39717 non-null  float64
#  37  out_prncp_inv                39717 non-null  float64
#  38  total_pymnt                  39717 non-null  float64
#  39  total_pymnt_inv              39717 non-null  float64
#  40  total_rec_prncp              39717 non-null  float64
#  41  total_rec_int                39717 non-null  float64
#  42  total_rec_late_fee           39717 non-null  float64
#  43  recoveries                   39717 non-null  float64
#  44  collection_recovery_fee      39717 non-null  object
#  45  last_pymnt_d                 39646 non-null  object
#  46  last_pymnt_amnt              39716 non-null  float64
#  47  next_pymnt_d                 1141 non-null   object
#  48  last_credit_pull_d           39715 non-null  object
#  49  collections_12_mths_ex_med   39660 non-null  float64
#  50  mths_since_last_major_derog  1 non-null      float64
#  51  policy_code                  39717 non-null  object
#  52  application_type             39716 non-null  object
#  53  verification_status_joint    1 non-null      float64
#  54  acc_now_delinq               39716 non-null  float64
#  55  bc_util                      1 non-null      float64
#  56  chargeoff_within_12_mths     39661 non-null  float64
#  57  delinq_amnt                  39716 non-null  float64
#  58  percent_bc_gt_75             1 non-null      float64
#  59  pub_rec_bankruptcies         39020 non-null  float64
#  60  tax_liens                    39677 non-null  float64
# dtypes: float64(25), int64(7), object(29)
# memory usage: 18.5+ MB

# %%
null_cols = df.columns[df.isnull().any()]
null_df = df[null_cols].isnull().sum().to_frame(name='Null Count')\
          .merge(df[null_cols].isnull().mean().mul(100).to_frame(name='Null Percent'), left_index=True, right_index=True)
null_df_sorted = null_df.sort_values(by='Null Count', ascending=False)
print(null_df_sorted)
# Out:
#                              Null Count  Null Percent
# mths_since_last_major_derog       39716           100
# percent_bc_gt_75                  39716           100
# bc_util                           39716           100
# verification_status_joint         39716           100
# next_pymnt_d                      38576            97
# mths_since_last_record            36930            93
# mths_since_last_delinq            25683            65
# desc                              12942            33
# emp_title                          2459             6
# emp_length                         1075             3
# pub_rec_bankruptcies                697             2
# last_pymnt_d                         71             0
# collections_12_mths_ex_med           57             0
# chargeoff_within_12_mths             56             0
# revol_util                           50             0
# tax_liens                            40             0
# title                                11             0
# last_credit_pull_d                    2             0
# application_type                      1             0
# acc_now_delinq                        1             0
# last_pymnt_amnt                       1             0
# delinq_amnt                           1             0

# %%
df=df.drop(['next_pymnt_d','mths_since_last_record','mths_since_last_delinq','pymnt_plan','url','initial_list_status'],axis=1)
df=df.drop(['collections_12_mths_ex_med','policy_code','acc_now_delinq','chargeoff_within_12_mths','delinq_amnt','pub_rec_bankruptcies','tax_liens','mths_since_last_major_derog','verification_status_joint','bc_util','percent_bc_gt_75'],axis=1)
df.shape
# Out:
# (39717, 44)

# %% [markdown]
# #### Missing Value Treatment

# %%
df[['desc','emp_title','title']]=df[['desc','emp_title','title']].fillna('Others')

# %%
null_cols = df.columns[df.isnull().any()]
null_df = df[null_cols].isnull().sum().to_frame(name='Null Count')\
          .merge(df[null_cols].isnull().mean().mul(100).to_frame(name='Null Percent'), left_index=True, right_index=True)
null_df_sorted = null_df.sort_values(by='Null Count', ascending=False)
print(null_df_sorted)
# Out:
#                     Null Count  Null Percent
# emp_length                1075             3
# last_pymnt_d                71             0
# revol_util                  50             0
# last_credit_pull_d           2             0
# last_pymnt_amnt              1             0
# application_type             1             0

# %%
df['emp_title'].value_counts()
# Out:
# emp_title
# Others                             2459
# US Army                             134
# Bank of America                     109
# IBM                                  66
# AT&T                                 59
#                                    ...
# AMEC                                  1
# lee county sheriff                    1
# Bacon County Board of Education       1
# Hotpads                               1
# Evergreen Center                      1
# Name: count, Length: 28821, dtype: int64

# %%
df=df.drop(['emp_title'],axis=1)
df.shape
# Out:
# (39717, 43)

# %% [markdown]
# #### Handling Incorrect Data Types

# %%
# df['term'] = df['term'].str.replace('months', '')
# df['term'] = df['term'].astype(int)

# %%
df['int_rate'] = df['int_rate'].str.replace('%', '')
df['int_rate'] = df['int_rate'].astype(float)

# %%
df['Updated_emp_length']=df['emp_length']
df['Updated_emp_length'] = df['Updated_emp_length'].fillna('-1')
df['Updated_emp_length'] = df['Updated_emp_length'].str.replace('years', '')
df['Updated_emp_length'] = df['Updated_emp_length'].str.replace('year', '')
df['Updated_emp_length'] = df['Updated_emp_length'].str.replace('+', '')    
df['Updated_emp_length'] = df['Updated_emp_length'].str.replace('< 1', '0') 
df['Updated_emp_length'] = df['Updated_emp_length'].astype(int)

# %%
df['emp_length'] = df['emp_length'].fillna('Data not provided')

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000             4975   36 months
# 1  1077430    1314167       2500         2500             2500   60 months
# 2  1077175    1313524       2400         2400             2400   36 months
# 3  1076863    1277178      10000        10000            10000   36 months
# 4  1075358    1311748       3000         3000             3000   60 months
#
#    int_rate  installment grade sub_grade  ... total_rec_prncp total_rec_int  \
# 0        11          163     B        B2  ...            5000           863
# 1        15           60     C        C4  ...             456           435
# 2        16           84     C        C5  ...            2400           606
# 3        13          339     C        C1  ...           10000          2215
# 4        13           68     B        B5  ...            2476          1037
#
#    total_rec_late_fee recoveries collection_recovery_fee last_pymnt_d  \
# 0                   0          0                       0       Jan-15
# 1                   0        117                       1       Apr-13
# 2                   0          0                       0       Jun-14
# 3                  17          0                       0       Jan-15
# 4                   0          0                       0       May-16
#
#   last_pymnt_amnt last_credit_pull_d application_type Updated_emp_length
# 0             172             May-16       INDIVIDUAL                 10
# 1             120             Sep-13       INDIVIDUAL                  0
# 2             650             May-16       INDIVIDUAL                 10
# 3             357             Apr-16       INDIVIDUAL                 10
# 4              68             May-16       INDIVIDUAL                  1
#
# [5 rows x 44 columns]

# %% [markdown]
# #### Sanity check

# %% [markdown]
# - Loan amount not less than funded_amnt.

# %%
df[(df['funded_amnt_inv']> df['loan_amnt'])].shape
# Out:
# (0, 44)

# %%
df.describe()
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# count   39717      39717      39717        39717            39717     39717
# mean   683132     850464      11219        10948            10397        12
# std    210694     265678       7457         7187             7128         4
# min     54734      70699        500          500                0         5
# 25%    516221     666780       5500         5400             5000         9
# 50%    665665     850812      10000         9600             8975        12
# 75%    837755    1047339      15000        15000            14400        15
# max   1077501    1314167      35000        35000            35000        25
#
#        installment  annual_inc   dti  inq_last_6mths  ...  out_prncp  \
# count        39717       39717 39717           39717  ...      39717
# mean           325       68969    13               1  ...         51
# std            209       63794     7               1  ...        375
# min             16        4000     0               0  ...          0
# 25%            167       40404     8               0  ...          0
# 50%            280       59000    13               1  ...          0
# 75%            431       82300    19               1  ...          0
# max           1305     6000000    30              16  ...       6311
#
#        out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# count          39717        39717            39717            39717
# mean              51        12153            11567             9793
# std              379         9042             8943             7066
# min                0            0                0                0
# 25%                0         5577             5112             4600
# 50%                0         9899             9288             8000
# 75%                0        16534            15799            13653
# max            12392        58564            58564            35000
#
#        total_rec_int  total_rec_late_fee  recoveries  last_pymnt_amnt  \
# count          39717               39717       39717            39716
# mean            2264                   1          95             2679
# std             2608                   7         689             4447
# min                0                   0           0                0
# 25%              662                   0           0              219
# 50%             1349                   0           0              546
# 75%             2833                   0           0             3293
# max            23564                 180       29623            36115
#
#        Updated_emp_length
# count               39717
# mean                    5
# std                     4
# min                    -1
# 25%                     2
# 50%                     4
# 75%                     9
# max                    10
#
# [8 rows x 22 columns]

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Interest Rate

# %% [markdown]
# 1.) Interest rates in the dataset ranges from 5% to 25%. <br>
# 2.) Interest rates above 22.5% are considered as outliers. <br>
# 3.) 25th, 50th and 75 the percentile values are 9%, 12%, 15% respectively.<br>
# 4.) According to the Histogram chart the frequency is high at around 11% followed by 7.5% and it gets reduced post 20%.

# %%
df['int_rate'].describe()
# Out:
# count   39717
# mean       12
# std         4
# min         5
# 25%         9
# 50%        12
# 75%        15
# max        25
# Name: int_rate, dtype: float64

# %%
df['int_rate'].plot.box()
plt.title('Box plot for interest rate')
# Out:
# Text(0.5, 1.0, 'Box plot for interest rate')

# %%
fig, axs = plt.subplots(figsize=(10,5))
sns.histplot(df, x="int_rate", bins=30)
plt.title('Frequency of interest rate provided by the investor')
# Out:
# Text(0.5, 1.0, 'Frequency of interest rate provided by the investor')

# %% [markdown]
# ## Loan Term

# %% [markdown]
# 1.) The consumer finance company is providing loan to its customer with two loan term period options 36 and 60 months.<br>
# 2.) Majority of the customers/borrowers are opting for 36 months loan period which amount to 73% of the total loan sanctioned.

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10,5))
df['term'].value_counts().plot.pie(autopct='%.1f%%',ax=axs[0])
axs[0].set_title('Loarn Term share')
graph=df['term'].value_counts().plot.bar(color=['red','green'])
plt.title('Loan Term Details')
plt.xlabel('Loan term in months')
percentage=(df['term'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%').tolist()
i = 0
for p in graph.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.text(x+width/2,
             y+height*1.01,
             str(percentage[i]),
             ha='center',
             weight='bold')
    i += 1
    
df['term'].value_counts()
# Out:
# term
#  36 months    29096
#  60 months    10621
# Name: count, dtype: int64

# %% [markdown]
# ### Loan Amount

# %% [markdown]
# 1.) Loan amount in the dataset ranges between 500 - 3500 (amount in dollars). <br>
# 2.) Loan amount above 30000 are considered as outliers. <br>
# 3.) 25th, 50th and 75 the percentile values are 5400, 9600, 15000 respectively. <br>
# 4.) According to the Histogram chart the frequency is high at around 5000 followed by 10000.

# %%
df['funded_amnt'].plot.box()
plt.title('Boxplot of Funded loan amount')
plt.show()
df['funded_amnt'].describe()
# Out:
# count   39717
# mean    10948
# std      7187
# min       500
# 25%      5400
# 50%      9600
# 75%     15000
# max     35000
# Name: funded_amnt, dtype: float64

# %%
fig, axs = plt.subplots(figsize=(10,5))
sns.histplot(df, x="funded_amnt", bins=30, color='red')
plt.title('Frequency of Loan amount sanctioned by the investor')
# Out:
# Text(0.5, 1.0, 'Frequency of Loan amount sanctioned by the investor')

# %% [markdown]
# ### Borrower's employment experience

# %% [markdown]
# 1.) Borrowers who has 10 + years of work experience acquired major chunk of loans from the company followed by borrows with <1 year experience and 2 years experience respectively
# 2.) 25th, 50th and 75 the percentile values are 2 years, 4 years, 9 years respectively.

# %%
df['Updated_emp_length'].describe()
# Out:
# count   39717
# mean        5
# std         4
# min        -1
# 25%         2
# 50%         4
# 75%         9
# max        10
# Name: Updated_emp_length, dtype: float64

# %%
df['emp_length'].value_counts().plot.pie(autopct='%.1f%%')
plt.ylabel('')
plt.title('Borrower work experience chart')
# Out:
# Text(0.5, 1.0, 'Borrower work experience chart')

# %% [markdown]
# ### Loan Status

# %% [markdown]
# 1.) About 83% of the applicants have fully paid (principal + interest rate) and the tenure of the loan is completed. <br>
# 2.) 2.9 % of the applicant are in the process of paying the instalments, i.e. the tenure of the loan is not yet completed. <br>
# 3.) About 14.2% of the applicant have defauted and their loan amount has been 'Charged off', this will be considered as financial loss to the company

# %%
df['loan_status'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='loan_status'>

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
df['loan_status'].value_counts().plot.pie(autopct='%.1f%%',ax=axs[0])
axs[0].set_title('Loan status distribution')
graph=df['loan_status'].value_counts().plot.bar(color=['green','red','blue'])
plt.title('Loan status')
plt.xlabel('Status')
percentage=(df['loan_status'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%').tolist()
i = 0
for p in graph.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.text(x+width/2,
             y+height*1.01,
             str(percentage[i]),
             ha='center',
             weight='bold')
    i += 1
    
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: count, dtype: int64

# %% [markdown]
# ### Loan Purpose

# %% [markdown]
# 1.) The major purpose of the applicants borrowing loan from the lending company is due to'debt consolidation' which amount to 46.9% (about half) followed by 'credit card' 12.9%.<br>
# 2.) Only 0.8 % of the applicant opt for education loan for vacation it slightly higher 1%.<br>

# %%
fig, axs = plt.subplots(ncols=1, figsize=(15,10))
graph=df['purpose'].value_counts().plot.bar(color=['green','red','blue'])
plt.title('Loan purpose')
plt.xlabel('purpose')
percentage=(df['purpose'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%').tolist()

i = 0
for p in graph.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
     
    plt.text(x+width/2,
             y+height*1.01,
             str(percentage[i])+'%',
             ha='center',
             weight='bold')
    i += 1
df['purpose'].value_counts()
# Out:
# purpose
# debt_consolidation             18641
# credit_card                     5129
# other                           3993
# home_improvement                2976
# major_purchase                  2187
# small_business                  1828
# car                             1549
# wedding                          947
# medical                          693
# moving                           583
# vacation                         381
# house                            381
# educational                      325
# renewable_energy                 103
# Paying off my son's dept...        1
# Name: count, dtype: int64

# %% [markdown]
# ### Income Verification status

# %% [markdown]
# - For about one third (42.6%) of the loans issued by the lending company, applicant's income was not verfied.
# - Only for 32% of the applicants income was verified whereas for about 25% of the applicants income source was verified.

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
df['verification_status'].value_counts().plot.pie(autopct='%.1f%%',ax=axs[0])
axs[0].set_title('Income verification status distribution')
graph=df['verification_status'].value_counts().plot.bar(color=['black','purple','orange'])
plt.title('Income verification status')
plt.xlabel('Verification Status')
percentage=(df['verification_status'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%').tolist()
i = 0
for p in graph.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.text(x+width/2,
             y+height*1.01,
             str(percentage[i]),
             ha='center',
             weight='bold')
    i += 1
    
df['verification_status'].value_counts()
# Out:
# verification_status
# Not Verified       16921
# Verified           12809
# Source Verified     9987
# Name: count, dtype: int64

# %% [markdown]
# ### Applicant's State (Region)

# %% [markdown]
# - Around 7000 applicants who borrowed Loan from the Lending company comes from 'California' followed by New York which has nearly 3800 applicants

# %%
fig, axs = plt.subplots(ncols=1, figsize=(15,5))
sns.countplot( x = 'addr_state', data = df, color = 'yellow', 
              order = df['addr_state'].value_counts().index[:20]);

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ### Borrower's home ownership status vs Loan Status (Defaulted/Charged off)

# %% [markdown]
# - Plotted a Bar graph between applicant's home owenership status and charged off loan status to get analyse whether home ownership parameter affects loan repaymenent.
# - The bar graph shows among the defaulted / charged off loan around 90% of applicants home ownership status is either 'Rent'(50%) or 'Mortgage'(41%).

# %%
df=df[-(df['home_ownership']=='NONE')]
df['home_ownership'].value_counts()
# Out:
# home_ownership
# RENT        18899
# MORTGAGE    17659
# OWN          3058
# OTHER          98
# Name: count, dtype: int64

# %%
df1=df[df['loan_status']=='Charged Off']
df1['id'].count()
# Out:
# 5627

# %%
fig, axs = plt.subplots(ncols=1, figsize=(10,5))
plots=sns.histplot(binwidth=0.5, x="loan_status", hue="home_ownership", data=df1, stat="count", multiple="dodge")
for bar in plots.patches:
    percentage=round(((bar.get_height()/df1['id'].count())*100),1)
    plots.annotate(format(str(percentage)+'%'), 
                   (bar.get_x() + bar.get_width() / 2, 
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
plt.show()

# %% [markdown]
# ### Interest Rate Vs Loan Status

# %%
df['int_rate_Bucket'] = pd.qcut(df['int_rate'], [0, 0.25, 0.5, 0.75,1], ["Low:5-8%","Nominal:9%-11%","High:12%-14%","High_risk:15%-25%"])

# %%
res = pd.pivot_table(data=df,index="loan_status",columns="int_rate_Bucket",values='int_rate',aggfunc='count')
print(res)
# Out:
# int_rate_Bucket  Low:5-8%  Nominal:9%-11%  High:12%-14%  High_risk:15%-25%
# loan_status
# Charged Off           600            1192          1524               2311
# Current                42             217           305                576
# Fully Paid           9383            8798          7821               6945

# %%
sns.heatmap(res,cmap = "Wistia", annot=True, fmt=',d')
plt.show()

# %%
res = pd.pivot_table(data=df,index="loan_status",columns="verification_status",values="member_id",aggfunc='count')
print(res)
# Out:
# verification_status  Not Verified  Source Verified  Verified
# loan_status
# Charged Off                  2142             1434      2051
# Current                       227              310       603
# Fully Paid                  14549             8243     10155

# %%
anual income vs loan status

# %%
res = pd.pivot_table(data=df,index="loan_status",columns="int_rate_Bucket",values='annual_inc',aggfunc='count')
print(res)
# Out:
# int_rate_Bucket  Low:5-8%  Nominal:9%-11%  High:12%-14%  High_risk:15%-25%
# loan_status
# Charged Off           600            1192          1524               2311
# Current                42             217           305                576
# Fully Paid           9383            8798          7821               6945
